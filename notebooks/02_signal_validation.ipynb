# %% [markdown]
# # EarningsIQ Signal Validation
# Built by Saif Mohammed · smohammed8@seattleu.edu · github.com/Mohammed-Saif-07
#
# Validate whether call-language signals aligned with post-call price direction.

# %%
import os
import pandas as pd
import psycopg

dsn = os.getenv('DATABASE_URL', 'postgresql://earningsiq:earningsiq@localhost:5432/earningsiq')
query = 'SELECT * FROM v_signal_accuracy ORDER BY total_calls DESC'
with psycopg.connect(dsn) as conn:
    accuracy = pd.read_sql(query, conn)
accuracy
