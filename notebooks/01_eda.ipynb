# %% [markdown]
# # EarningsIQ EDA
# Built by Saif Mohammed · smohammed8@seattleu.edu · github.com/Mohammed-Saif-07
#
# Exploratory analysis for transcript volume, sentence sentiment, anomaly density, and signal distribution.

# %%
import os
import pandas as pd
import psycopg

dsn = os.getenv('DATABASE_URL', 'postgresql://earningsiq:earningsiq@localhost:5432/earningsiq')
with psycopg.connect(dsn) as conn:
    filings = pd.read_sql('SELECT * FROM v_filing_summary ORDER BY filed_at DESC LIMIT 100', conn)
filings.head()
