# %% [markdown]
# # EarningsIQ SQL Analytics
# Built by Saif Mohammed · smohammed8@seattleu.edu · github.com/Mohammed-Saif-07
#
# Pure SQL analytics notebook for materialized views, full-text search, and speaker analysis.

# %%
import os
import psycopg

dsn = os.getenv('DATABASE_URL', 'postgresql://earningsiq:earningsiq@localhost:5432/earningsiq')
sql = open('../sql/queries/weekly_report.sql').read()
with psycopg.connect(dsn) as conn:
    with conn.cursor() as cur:
        cur.execute(sql)
        rows = cur.fetchall()
rows[:10]
